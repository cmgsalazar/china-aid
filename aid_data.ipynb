# %%
import pandas as pd
import requests

# %%
# chooses only a specific sheet from the Excel file
df = pd.read_excel('AidDatasGlobalChineseDevelopmentFinanceDataset_v3.0.xlsx', sheet_name='GCDF_3.0')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20985 entries, 0 to 20984
# Columns: 126 entries, AidData Record ID to Loan Detail Score
# dtypes: datetime64[ns](7), float64(24), int64(7), object(88)
# memory usage: 20.2+ MB

# %%
# filters data points to only show 'Asia' under 'Recipient Region'
df = df[df['Recipient Region'] == 'Asia']
df.head(3)
# Out:
#    AidData Record ID Recommended For Aggregates AidData Parent ID Umbrella  \
# 0              94556                        Yes               NaN       No
# 1              94564                        Yes               NaN       No
# 2              94565                        Yes               NaN       No
#
#               Financier Country    Recipient Recipient ISO-3 Recipient Region  \
# 0  China (People's Republic of)  Afghanistan             AFG             Asia
# 1  China (People's Republic of)  Afghanistan             AFG             Asia
# 2  China (People's Republic of)  Afghanistan             AFG             Asia
#
#    Commitment Year  Implementation Start Year  ...  OECD ODA Income Group  \
# 0             2021                     2021.0  ...             Low income
# 1             2021                     2021.0  ...             Low income
# 2             2021                     2021.0  ...             Low income
#
#             Location Narrative Geographic Level of Precision Available  \
# 0  No location info available.                                     NaN
# 1                          NaN                                     NaN
# 2            Kabul Afghanistan                                     NaN
#
#   ADM1 Level Available ADM2 Level Available Geospatial Feature Available  \
# 0                  NaN                  NaN                          NaN
# 1                  NaN                  NaN                          NaN
# 2                  NaN                  NaN                          NaN
#
#   Source Quality Score Data Completeness Score  Implementation Detail Score  \
# 0                    5                       3                          4.0
# 1                    5                       3                          4.0
# 2                    4                       3                          5.0
#
#   Loan Detail Score
# 0               NaN
# 1               NaN
# 2               NaN
#
# [3 rows x 126 columns]

# %%
# shows list of 'Recipient' and number of unique records
df.groupby('Recipient')['AidData Record ID'].nunique()
# Out:
# Recipient
# Afghanistan                              169
# Armenia                                   52
# Asia, regional                            54
# Azerbaijan                                53
# Bangladesh                               175
# Brunei Darussalam                         53
# Cambodia                                 418
# Democratic People's Republic of Korea    148
# Georgia                                   52
# India                                    113
# Indonesia                                437
# Kazakhstan                               181
# Kyrgyz Republic                          146
# Lao People's Democratic Republic         346
# Malaysia                                 176
# Maldives                                 101
# Mongolia                                 232
# Myanmar                                  495
# Nepal                                    222
# Pakistan                                 496
# Philippines                              267
# Sri Lanka                                301
# Tajikistan                               172
# Thailand                                 116
# Timor-Leste                              131
# Turkmenistan                              53
# Uzbekistan                               196
# Viet Nam                                 191
# Name: AidData Record ID, dtype: int64

# %%
# filtering non-SEA rows

exclude_rows = ['Afghanistan', 'Armenia', 'Azerbaijan', "Democratic People's Republic of Korea", 'Georgia', 'India', 'Kazakhstan', 'Kyrgyz Republic', 'Maldives', 'Mongolia', 'Nepal', 'Pakistan', 'Sri Lanka', 'Tajikistan', 'Turkmenistan', 'Uzbekistan']
filtered_df = df[~df['Recipient'].str.contains('|'.join(exclude_rows))]

# %%
filtered_df.groupby('Recipient')['AidData Record ID'].nunique()
# Out:
# Recipient
# Asia, regional                       54
# Bangladesh                          175
# Brunei Darussalam                    53
# Cambodia                            418
# Indonesia                           437
# Lao People's Democratic Republic    346
# Malaysia                            176
# Myanmar                             495
# Philippines                         267
# Thailand                            116
# Timor-Leste                         131
# Viet Nam                            191
# Name: AidData Record ID, dtype: int64

# %%
filtered_df.dtypes
# Out:
# AidData Record ID                 int64
# Recommended For Aggregates       object
# AidData Parent ID                object
# Umbrella                         object
# Financier Country                object
#                                  ...
# Geospatial Feature Available     object
# Source Quality Score              int64
# Data Completeness Score           int64
# Implementation Detail Score     float64
# Loan Detail Score               float64
# Length: 126, dtype: object

# %%
# finding a string or keyword in all cells
# keep only rows that have the search keywork

search_string = 'petrochemical'

def check_string(cell):
    return search_string in str(cell)

mask = filtered_df.map(check_string).any(axis=1)
new_df = filtered_df[mask]
new_df.head(3)
# Out:
#       AidData Record ID Recommended For Aggregates AidData Parent ID Umbrella  \
# 4036              89494                        Yes                31       No
# 4037              89495                        Yes                31       No
# 4038              89496                        Yes                31       No
#
#                  Financier Country Recipient Recipient ISO-3 Recipient Region  \
# 4036  China (People's Republic of)  Malaysia             MYS             Asia
# 4037  China (People's Republic of)  Malaysia             MYS             Asia
# 4038  China (People's Republic of)  Malaysia             MYS             Asia
#
#       Commitment Year  Implementation Start Year  ...  OECD ODA Income Group  \
# 4036             2019                        NaN  ...    Upper middle income
# 4037             2019                        NaN  ...    Upper middle income
# 4038             2019                        NaN  ...    Upper middle income
#
#                                      Location Narrative  \
# 4036  The purpose of the project is to construct a r...
# 4037  The purpose of the project is to construct a r...
# 4038  The purpose of the project is to construct a r...
#
#      Geographic Level of Precision Available ADM1 Level Available  \
# 4036                                 Precise                  Yes
# 4037                                 Precise                  Yes
# 4038                                 Precise                  Yes
#
#      ADM2 Level Available Geospatial Feature Available Source Quality Score  \
# 4036                  Yes                          Yes                    5
# 4037                  Yes                          Yes                    5
# 4038                  Yes                          Yes                    5
#
#      Data Completeness Score  Implementation Detail Score Loan Detail Score
# 4036                       4                          2.0               4.0
# 4037                       4                          2.0               4.0
# 4038                       4                          2.0               4.0
#
# [3 rows x 126 columns]

# %%
new_df.to_csv('data.csv')

# %%
# exclude / drop unnecessary columns
# LED TO SYNTAX ERROR: exclude_columns = ['Recipient ISO-3', 'Recipient Region', 'Flow Type', 'OECD ODA Concessionality Threshold', 'Flow Class', 'Sector Code', 'COVID', 'Guarantee Provided', 'Guarantor', 'Guarantor Agency Type', 'Insurance Provided', 'Insurance Provider', 'Insurance Provider Agency Type', 'Collateralized', 'Collateral Provider', 'Collateral Provider Agency Type', 'Security Agent/Collateral Agent', 'Security Agent/Collateral Agent Type', 'Collateral', 49:54, 56:57, 63:127]

exclude_columns = ['Recipient ISO-3', 'Recipient Region', 'Flow Type', 'OECD ODA Concessionality Threshold', 'Flow Class', 'Sector Code', 'COVID', 'Guarantee Provided', 'Guarantor', 'Guarantor Agency Type', 'Insurance Provided', 'Insurance Provider', 'Insurance Provider Agency Type', 'Collateralized', 'Collateral Provider', 'Collateral Provider Agency Type', 'Security Agent/Collateral Agent', 'Security Agent/Collateral Agent Type', 'Collateral']

# add ranges to the list
exclude_columns += list(range(49, 55))
exclude_columns += list(range(56, 58))
exclude_columns += list(range(63, 128))

new_df.drop(columns=exclude_columns)
new_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 11
#       8 exclude_columns += list(range(56, 58))
#       9 exclude_columns += list(range(63, 128))
# ---> 11 new_df.drop(columns=exclude_columns)
#      12 new_df.dtypes
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: '[49, 50, 51, 52, 53, 54, 56, 57, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127] not found in axis'
